# %%
#importing neccesary library
import pandas as pd

#reading the dataset
data = pd.read_csv("/content/drive/MyDrive/extreme_changes_post.csv")
data.head(10)
# Out:
#         bvdid  numberofemployees        date  \
# 0  GB00138691                284  11/20/2013
# 1  GB00138691                284   5/27/2014
# 2  GB00138691                284   9/18/2014
# 3  GB00138691                284  11/25/2014
# 4  GB00138691                284  12/31/2015
# 5  GB00138691                284  10/16/2016
# 6  GB00138691                284   5/12/2017
# 7  GB00138691                284    2/7/2018
# 8  GB00138691                284  10/31/2018
# 9  GB00138691                284   4/25/2021
#
#                                                title  \
# 0  Learned a lot on the job, more than any other ...
# 1                                    Human Resources
# 2                                          Great job
# 3      Firth Rixson - the Good, the Bad and the Ugly
# 4                                            Manager
# 5                               Supply Chain Manager
# 6                                          Inspector
# 7                                      Busy business
# 8           Shipping dept Lead logistics coordinator
# 9                                               Good
#
#                                                  pro  \
# 0  Small company feel, good location, learn a lot...
# 1  Company afforded many opportunities to learn a...
# 2                        great pay, quarterly bonus,
# 3  Nice small company.  All shop floor workers ar...
# 4  Great opportunities when organization first st...
# 5    Good People who care about growing the business
# 6  Lots of overtime. Great if you don't have a fa...
# 7  Size is not too big, presence of affiliates ma...
# 8  Made good money from all the over time you wer...
# 9                Good pay, good freedom and benefits
#
#                                                 cons  advice  recommend  \
# 0          hours get rough and expectations are high     NaN        1.0
# 1  limited opportunities to move up unless someon...     NaN        1.0
# 2                  very hot and greasy place to work     NaN        1.0
# 3  company owned by investment firm.  thus, profi...     NaN       -1.0
# 4  has gone through four hr people in 5 years. co...     NaN        NaN
# 5                 high growth led to some long hours     NaN        1.0
# 6  too much overtime. horrible if you have a fami...     NaN       -1.0
# 7         little opportunities, not open to new ways     NaN        NaN
# 8  if you didn’t put in the mandatory 80 hours on...     NaN       -1.0
# 9  i never experienced any restrictions or cons w...     NaN        1.0
#
#    CEOapproval  outlook  ...  switchers  cost_employees_new_2019  \
# 0          1.0      NaN  ...          0                      NaN
# 1          1.0      1.0  ...          0                      NaN
# 2          NaN      NaN  ...          0                      NaN
# 3          0.0      NaN  ...          0                      NaN
# 4          NaN      NaN  ...          0                      NaN
# 5          1.0      1.0  ...          0                      NaN
# 6         -1.0      1.0  ...          0                      NaN
# 7          NaN      NaN  ...          0                      NaN
# 8         -1.0     -1.0  ...          0                      NaN
# 9          1.0      1.0  ...          0                      NaN
#
#    cost_employees_new_2016       _merge  extreme_change_pre_post  \
# 0                     55.0  matched (3)                        1
# 1                     55.0  matched (3)                        1
# 2                     55.0  matched (3)                        1
# 3                     55.0  matched (3)                        1
# 4                     55.0  matched (3)                        1
# 5                     55.0  matched (3)                        1
# 6                     55.0  matched (3)                        1
# 7                     55.0  matched (3)                        1
# 8                     55.0  matched (3)                        1
# 9                     55.0  matched (3)                        1
#
#    pos_extreme_change_pre_post  neg_extreme_change_pre_post  \
# 0                          NaN                          1.0
# 1                          NaN                          1.0
# 2                          NaN                          1.0
# 3                          NaN                          1.0
# 4                          NaN                          1.0
# 5                          NaN                          1.0
# 6                          NaN                          1.0
# 7                          NaN                          1.0
# 8                          NaN                          1.0
# 9                          NaN                          1.0
#
#   extreme_change_post pos_extreme_change_post  neg_extreme_change_post
# 0                   1                     NaN                      1.0
# 1                   1                     NaN                      1.0
# 2                   1                     NaN                      1.0
# 3                   1                     NaN                      1.0
# 4                   1                     NaN                      1.0
# 5                   1                     NaN                      1.0
# 6                   1                     NaN                      1.0
# 7                   1                     NaN                      1.0
# 8                   1                     NaN                      1.0
# 9                   1                     NaN                      1.0
#
# [10 rows x 170 columns]

# %% [markdown]
# Title column -most common words

# %%
#writing a code to run through the dataset TITLE column to rank most common words

#initializing empty list to store the split words from the dataframe
words_list = []
new_list=[]
final_list=[]
most_common_words1 = []
dictionary_value_count = {}

#iterating through the Title column and replacing all any words split by . and  / with '', for easy splitting
for word in data['title']:
    words_list.append(word.replace('.', ''))
    words_list.append(word.replace('/', ''))
    words_list.append(word.replace('-', ''))

#iterating through the word_list and converting all words to a string
for val in words_list:
  output1=str(val)
  new_list.append(output1)

#iterating through the new_list and splitting all the words and storing them in a new list called final_list
for n_val in new_list:
  output2=n_val.split()
  for res in output2:
    final_list.append(res)

#iterating through final_list and storing all split words into a dictionary
for word in final_list:
    if word not in dictionary_value_count:
        dictionary_value_count[word] = 1
    else:
        num = dictionary_value_count[word]
        dictionary_value_count[word] = (num + 1)

#function for obtaining the largest word count and aggreating them all
def largest_value(value):
    res = 0
    new_str = ''
    for key, val in value.items():
        if val > res:
            res = val
            new_str = key
    return [res, new_str]

#function for grouping all common words and ranking them together
def common_words( value,target):
    while len(most_common_words1) < target:
        most_common_words1.append(largest_value(value))
        del value[(largest_value(value)[1])]

common_words( dictionary_value_count,935)

print(most_common_words1)
# Out:
# [[207, 'Great'], [207, 'to'], [168, 'Good'], [165, 'work'], [144, 'company'], [126, 'place'], [120, 'and'], [97, 'for'], [96, 'a'], [84, 'the'], [81, 'Company'], [66, 'with'], [60, 'great'], [57, 'Not'], [51, 'of'], [51, 'in'], [48, 'good'], [47, 'job'], [36, 'A'], [30, 'Place'], [30, 'environment'], [28, 'Manager'], [28, 'you'], [27, 'experience'], [27, 'working'], [27, 'management'], [27, 'pay'], [27, 'not'], [27, 'Work'], [27, 'Engineer'], [27, 'is'], [24, 'but'], [21, 'No'], [21, 'at'], [21, 'Excellent'], [18, 'Bad'], [18, 'that'], [18, 'Ok'], [18, 'people'], [18, 'Very'], [18, 'as'], [18, 'Decent'], [18, 'Nice'], [18, 'like'], [16, 'culture'], [15, 'on'], [15, 'review'], [15, 'Amazing'], [15, 'Job'], [15, 'Assistant'], [15, 'manager'], [15, 'team'], [15, 'no'], [15, 'want'], [15, 'Management'], [15, 'this'], [15, 'people,'], [15, 'Best'], [15, 'worst'], [13, 'growth'], [12, 'can'], [12, 'your'], [12, 'Awful'], [12, 'an'], [12, 'Would'], [12, 'my'], [12, 'be'], [12, 'terrible'], [12, 'I'], [12, 'Experience'], [12, 'My'], [12, 'The'], [12, 'Account'], [12, 'People'], [12, 'ever'], [10, 'recommend'], [10, 'family'], [9, 'lot'], [9, 'Supervisor'], [9, 'well'], [9, 'it'], [9, 'career'], [9, 'learning'], [9, 'bad'], [9, 'very'], [9, 'engineering'], [9, 'Poor'], [9, '&'], [9, 'Could'], [9, 'benefits'], [9, 'Service'], [9, 'Business'], [9, 'company,'], [9, 'Environment'], [9, 'Review'], [9, 'its'], [9, 'school'], [9, 'start'], [9, 'Culture'], [9, 'where'], [9, 'about'], [9, 'Terrible'], [9, 'Worst'], [9, 'Fair'], [9, 'Working'], [9, 'Technician'], [9, 'thinking'], [9, 'outside'], [9, 'nice'], [9, 'High'], [9, 'if'], [8, '-'], [7, 'business'], [7, 'atmosphere'], [6, 'Learned'], [6, 'more'], [6, 'Human'], [6, 'Resources'], [6, 'Good,'], [6, 'Lead'], [6, "Don't"], [6, 'go'], [6, 'Only'], [6, 'enough'], [6, 'part'], [6, 'time'], [6, 'An'], [6, 'hard'], [6, 'work.'], [6, 'Great!'], [6, 'Manufacturing'], [6, 'Office'], [6, 'top'], [6, 'poor'], [6, 'International'], [6, 'somewhere'], [6, 'will'], [6, 'all'], [6, 'Negative'], [6, 'Quality'], [6, 'Fruit'], [6, 'loom'], [6, 'It'], [6, 'cares'], [6, 'Okay'], [6, 'Administrative'], [6, 'amazing'], [6, 'average'], [6, 'Analyst'], [6, 'best'], [6, 'Was'], [6, 'salary'], [6, 'better'], [6, 'employer'], [6, 'was'], [6, 'Internship'], [6, 'are'], [6, 'Salary'], [6, 'Mechanical'], [6, 'Family'], [6, 'Wonderful'], [6, 'have'], [6, 'what'], [6, 'they'], [6, 'bad,'], [6, 'okay'], [6, 'old'], [6, 'values'], [6, 'experience,'], [6, 'Mesa'], [6, 'Really'], [6, 'Claims'], [6, 'employees'], [6, 'Lack'], [6, 'colleagues'], [6, 'If'], [6, 'term'], [6, 'changes'], [6, 'work!'], [6, "I've"], [6, 'Change'], [6, 'Customer'], [6, 'Company,'], [6, 'or'], [6, 'sales'], [6, 'technology'], [6, 'Awesome'], [6, 'firm'], [6, 'Hard'], [6, 'Stay'], [6, 'decent'], [6, 'Gone'], [6, 'Fast'], [6, 'thing'], [6, 'products'], [6, 'staff'], [6, 'lies'], [6, 'Supportive'], [6, 'too'], [6, 'workplace'], [6, 'Unprofessional'], [6, 'Lovely'], [6, 'relaxed'], [6, 'Sales'], [6, 'friendly'], [6, 'run'], [6, 'Great,'], [6, 'Look'], [6, 'Do'], [6, 'Alright'], [6, 'worked'], [6, 'fake'], [6, 'employee'], [6, 'far'], [6, 'Forward'], [6, 'Trainee'], [6, 'Nurse'], [6, 'Case'], [6, 'MT'], [6, 'Avoid'], [4, 'job.'], [4, '.'], [4, 'areas'], [4, 'had'], [4, 'Admin'], [4, 'field'], [4, 'challenge'], [3, 'job,'], [3, 'than'], [3, 'any'], [3, 'other'], [3, 'entry'], [3, 'Firth'], [3, 'Rixson'], [3, 'Ugly'], [3, 'Supply'], [3, 'Chain'], [3, 'Inspector'], [3, 'Busy'], [3, 'Shipping'], [3, 'dept'], [3, 'logistics'], [3, 'coordinator'], [3, 'expect'], [3, 'CORPORATE'], [3, 'BULLYING'], [3, 'IS'], [3, 'RIFE!!!'], [3, 'Thrilling'], [3, 'environnement'], [3, 'stopped'], [3, 'lucky'], [3, 'get'], [3, 'another'], [3, 'Overused'], [3, 'undervalued'], [3, 'enjoyable'], [3, 'excellent'], [3, 'compensated'], [3, 'Regional'], [3, 'Oklahoma'], [3, 'worth'], [3, 'improvement'], [3, 'don'], [3, 'GIS,'], [3, 'Interpublic'], [3, 'Group'], [3, 'Politically'], [3, 'min ...

# %% [markdown]
# PRO column -most common words

# %%
#writing a code to run through the dataset pro column to rank most common words

#initializing empty list to store the split words from the dataframe
words_list = []
new_list=[]
final_list=[]
most_common_words2 = []
dictionary_value_count = {}

#iterating through the Title column and replacing all any words split by . and  / with '', for easy splitting
for word in data['pro']:
    words_list.append(word.replace('.', ''))
    words_list.append(word.replace('/', ''))
    words_list.append(word.replace('-', ''))

#iterating through the word_list and converting all words to a string
for val in words_list:
  output1=str(val)
  new_list.append(output1)

#iterating through the new_list and splitting all the words and storing them in a new list called final_list
for n_val in new_list:
  output2=n_val.split()
  for res in output2:
    final_list.append(res)

#iterating through final_list and storing all split words into a dictionary
for word in final_list:
    if word not in dictionary_value_count:
        dictionary_value_count[word] = 1
    else:
        num = dictionary_value_count[word]
        dictionary_value_count[word] = (num + 1)

#function for obtaining the largest word count and aggreating them all
def largest_value(value):
    res = 0
    new_str = ''
    for key, val in value.items():
        if val > res:
            res = val
            new_str = key
    return [res, new_str]

#function for grouping all common words and ranking them together
def common_words( value,target):
    while len(most_common_words2) < target:
        most_common_words2.append(largest_value(value))
        del value[(largest_value(value)[1])]

common_words( dictionary_value_count,935)

print(most_common_words2)
# Out:
# [[1113, 'and'], [814, 'to'], [660, 'the'], [462, 'a'], [384, 'of'], [381, 'work'], [369, 'is'], [345, 'are'], [293, 'good'], [276, 'in'], [265, 'for'], [258, 'I'], [245, 'Great'], [242, 'with'], [237, 'you'], [234, 'Good'], [219, 'company'], [212, 'great'], [192, 'people'], [180, 'The'], [154, 'working'], [149, 'on'], [135, 'have'], [129, 'that'], [126, 'very'], [123, 'at'], [120, 'your'], [118, '-'], [111, 'place'], [108, 'as'], [107, 'benefits'], [99, 'was'], [97, 'environment'], [96, 'get'], [94, 'team'], [93, 'this'], [91, 'management'], [87, 'staff'], [86, 'friendly'], [81, 'pay'], [80, 'job'], [79, 'can'], [74, 'nice'], [73, 'employees'], [72, 'some'], [72, 'really'], [69, 'new'], [68, 'be'], [67, 'it'], [66, 'from'], [63, 'if'], [63, 'but'], [63, 'no'], [63, 'they'], [63, 'their'], [61, 'learn'], [57, 'not'], [57, 'were'], [57, 'hours'], [57, 'There'], [54, 'all'], [54, 'like'], [54, 'an'], [51, 'well'], [51, 'about'], [51, 'or'], [49, 'up'], [49, 'will'], [48, 'when'], [48, 'who'], [48, 'They'], [48, 'Work'], [46, 'lot'], [46, 'life'], [46, 'time'], [45, 'many'], [45, 'opportunities'], [45, 'we'], [44, 'colleagues'], [42, 'always'], [42, 'training'], [42, 'environment,'], [42, 'experience'], [42, 'do'], [42, 'here'], [40, 'so'], [40, 'You'], [40, 'other'], [39, 'Very'], [39, 'has'], [39, 'worked'], [39, 'by'], [39, 'family'], [39, 'people,'], [39, 'make'], [39, 'things'], [39, 'enjoy'], [39, 'my'], [38, 'balance'], [37, 'positive'], [37, 'culture'], [36, 'Nice'], [36, 'Lots'], [36, 'our'], [36, 'there'], [36, 'products'], [35, 'had'], [34, 'People'], [34, 'work.'], [34, 'office'], [34, 'Flexible'], [34, 'learning'], [34, 'fun'], [33, 'what'], [33, 'opportunity'], [33, 'Friendly'], [33, 'It'], [32, 'atmosphere'], [32, 'coworkers'], [32, 'flexible'], [31, 'hard'], [30, 'been'], [30, 'company.'], [30, 'Some'], [30, 'If'], [30, 'work,'], [30, 'people.'], [30, 'feel'], [29, 'more'], [29, 'support'], [28, 'help'], [28, 'best'], [27, 'most'], [27, 'company,'], [27, 'any'], [27, 'location'], [27, 'me'], [27, 'employee'], [26, 'it.'], [26, 'group'], [26, 'clients'], [25, 'challenging'], [25, 'career'], [24, 'out'], [24, 'only'], [24, 'right'], [24, 'need'], [24, 'supportive'], [24, 'across'], [24, 'free'], [24, 'day'], [24, 'growth'], [24, 'culture,'], [24, 'A'], [24, 'want'], [24, 'being'], [24, 'No'], [24, 'because'], [22, 'small'], [22, 'business'], [22, 'paid'], [22, 'good.'], [22, 'quality'], [22, 'development'], [21, 'too'], [21, 'Free'], [21, 'Interesting'], [21, 'take'], [21, "it's"], [21, 'This'], [21, 'know'], [21, 'pros'], [21, 'long'], [21, 'doing'], [21, 'Management'], [21, 'see'], [21, 'health'], [21, 'technology'], [21, 'different'], [21, 'managers'], [21, 'one'], [21, 'Excellent'], [21, 'benefits,'], [21, 'willing'], [21, 'where'], [21, 'which'], [20, 'workers'], [20, 'far'], [20, 'better'], [20, 'environment.'], [20, 'amazing'], [20, 'home'], [20, 'within'], [20, 'off'], [20, 'easy'], [19, 'projects'], [19, 'started'], [19, 'door'], [18, 'Company'], [18, 'care'], [18, 'interesting'], [18, 'after'], [18, 'friendly,'], [18, 'ever'], [18, 'Pay'], [18, 'never'], [18, 'role'], [18, "you're"], [18, 'grow'], [18, 'own'], [18, 'relaxed'], [18, 'passionate'], [18, 'clients,'], [18, 'available'], [18, 'develop'], [18, 'close'], [18, 'still'], [18, 'awesome'], [18, 'As'], [17, 'overtime'], [17, 'back'], [16, 'benefits.'], [16, 'manager'], [16, 'times'], [16, 'encouraged'], [16, 'excellent'], [16, 'with.'], [16, "It's"], [16, 'potential'], [16, 'balance.'], [16, 'process'], [16, 'days'], [16, 'going'], [16, 'Nothing'], [16, 'insurance'], [16, 'Emerald'], [15, 'Small'], [15, 'compensation'], [15, 'way'], [15, 'person'], [15, 'also'], [15, 'first'], [15, 'dedicated'], [15, 'would'], [15, 'salary'], [15, 'Plenty'], [15, 'even'], [15, 'level'], [15, 'None'], [15, 'market'], [15, 'large'], [15, 'lunch'], [15, 'move'], [15, 'just'], [15, 'open'], [15, '&'], [15, 'wonderful'], [15, 'allows'], [15, 'years'], [15, 'It’s'], [15, 'Su ...

# %% [markdown]
# CONS column -most common words

# %%
#writing a code to run through the dataset cons column to rank most common words

#initializing empty list to store the split words from the dataframe
words_list = []
new_list=[]
final_list=[]
most_common_words3 = []
dictionary_value_count = {}

#iterating through the Title column and replacing all any words split by . and  / with '', for easy splitting
for word in data['cons']:
    words_list.append(word.replace('.', ''))
    words_list.append(word.replace('/', ''))
    words_list.append(word.replace('-', ''))


#iterating through the word_list and converting all words to a string
for val in words_list:
  output1=str(val)
  new_list.append(output1)

#iterating through the new_list and splitting all the words and storing them in a new list called final_list
for n_val in new_list:
  output2=n_val.split()
  for res in output2:
    final_list.append(res)

#iterating through final_list and storing all split words into a dictionary
for word in final_list:
    if word not in dictionary_value_count:
        dictionary_value_count[word] = 1
    else:
        num = dictionary_value_count[word]
        dictionary_value_count[word] = (num + 1)

#function for obtaining the largest word count and aggreating them all
def largest_value(value):
    res = 0
    new_str = ''
    for key, val in value.items():
        if val > res:
            res = val
            new_str = key
    return [res, new_str]

#function for grouping all common words and ranking them together
def common_words( value,target):
    while len(most_common_words3) < target:
        most_common_words3.append(largest_value(value))
        del value[(largest_value(value)[1])]

common_words( dictionary_value_count,935)

print(most_common_words3)
# Out:
# [[1413, 'the'], [1316, 'to'], [1167, 'and'], [744, 'a'], [726, 'of'], [720, 'is'], [560, 'for'], [515, 'not'], [514, 'in'], [496, 'no'], [428, 'you'], [386, 'are'], [366, 'they'], [346, 'management'], [342, 'i'], [337, 'work'], [313, 'be'], [306, 'with'], [285, 'on'], [279, 'have'], [277, 'very'], [271, 'that'], [263, 'company'], [260, 'it'], [255, 'was'], [253, 'at'], [212, 'there'], [201, 'their'], [190, 'this'], [180, 'or'], [174, 'but'], [171, 'from'], [162, 'as'], [160, 'can'], [151, 'employees'], [148, 'pay'], [146, 'all'], [144, 'if'], [138, 'do'], [132, 'by'], [132, 'about'], [124, '-'], [122, 'get'], [122, 'out'], [120, 'so'], [120, 'time'], [118, 'job'], [116, 'people'], [115, 'working'], [111, 'has'], [111, 'my'], [109, 'staff'], [105, 'will'], [105, 'when'], [100, 'many'], [99, 'long'], [99, 'your'], [99, 'low'], [99, 'lack'], [98, 'hours'], [97, 'more'], [94, 'much'], [94, 'good'], [90, 'were'], [89, 'other'], [85, 'any'], [84, 'who'], [84, 'like'], [84, 'an'], [82, "don't"], [82, 'only'], [81, 'up'], [81, 'too'], [81, 'poor'], [80, 'some'], [79, 'high'], [78, 'could'], [75, 'little'], [75, 'being'], [72, 'than'], [72, 'would'], [71, 'place'], [69, 'really'], [69, 'none'], [69, 'what'], [69, 'just'], [69, 'had'], [67, 'bad'], [66, 'cons'], [66, 'he'], [66, 'which'], [65, 'training'], [64, 'one'], [63, 'think'], [62, 'great'], [60, 'been'], [60, 'office'], [58, 'over'], [57, 'hr'], [57, 'day'], [57, 'because'], [57, 'its'], [57, 'make'], [57, 'we'], [56, 'growth'], [56, 'way'], [54, "it's"], [54, 'new'], [54, 'room'], [54, '&'], [54, 'how'], [54, 'lot'], [51, 'even'], [51, 'environment'], [50, 'team'], [48, 'senior'], [48, 'know'], [48, 'management,'], [48, 'does'], [47, 'ceo'], [46, 'culture'], [45, 'due'], [45, 'take'], [45, 'need'], [45, 'most'], [44, 'life'], [43, 'everything'], [43, 'leadership'], [43, 'small'], [42, 'sales'], [42, 'go'], [42, 'off'], [42, 'always'], [42, 'slow'], [42, 'upper'], [41, 'business'], [41, 'here'], [40, 'home'], [40, 'hard'], [40, 'after'], [40, 'nothing'], [39, 'opportunities'], [39, 'want'], [39, "doesn't"], [39, 'managers'], [39, 'communication'], [39, 'salary'], [38, 'limited'], [38, 'enough'], [38, 'ever'], [37, 'manager'], [37, 'years'], [37, 'family'], [36, 'through'], [36, 'never'], [36, 'given'], [36, 'don’t'], [36, 'without'], [36, 'sometimes'], [36, 'still'], [36, 'turnover'], [36, 'those'], [35, 'anything'], [35, 'career'], [35, 'few'], [35, 'say'], [34, 'things'], [34, 'difficult'], [33, 'into'], [33, 'worked'], [33, 'told'], [33, 'every'], [33, 'our'], [33, 'them'], [33, 'customers'], [32, 'better'], [32, 'doing'], [32, 'change'], [32, 'company.'], [31, 'balance'], [31, 'care'], [31, 'market'], [30, 'before'], [30, 'days'], [30, 'well'], [30, 'see'], [30, 'work.'], [30, 'then'], [30, 'lots'], [30, 'expect'], [30, 'down'], [30, 'us'], [30, 'made'], [30, 'during'], [30, 'also'], [30, 'bit'], [29, 'position'], [29, 'department'], [28, 'now'], [28, 'benefits'], [28, 'door'], [28, 'far'], [27, 'put'], [27, 'did'], [27, 'stress'], [27, 'leaving'], [27, 'especially'], [27, 'should'], [27, 'short'], [27, 'terrible'], [27, 'going'], [27, 'within'], [27, 'employee'], [27, 'company,'], [26, 'money'], [25, 'back'], [25, 'between'], [25, 'everyone'], [25, 'holidays'], [25, 'top'], [25, 'development'], [25, 'support'], [25, 'use'], [24, 'customer'], [24, 'complete'], [24, 'while'], [24, 'his'], [24, 'zero'], [24, 'treated'], [24, 'below'], [24, 'advancement'], [24, 'since'], [24, 'got'], [24, "can't"], [24, 'supervisors'], [24, 'having'], [24, 'find'], [24, 'production'], [24, '•'], [24, 'me'], [24, 'each'], [24, 'feel'], [24, 'under'], [24, 'across'], [24, 'worst'], [23, 'year'], [22, 'though'], [22, 'another'], [22, 'talk'], [22, 'projects'], [22, 'issues'], [22, 'longer'], [22, 'left'], [22, 'future'], [22, 'around'], [22, 'respect'], [22, 'progression'], [22, 'teams'], [21, 'come'], [21, 'seem'], [21, 'bullying'], [21, 'treat'], [21, 'first'], [21, 'despite'], [21, 'average'],  ...

# %%
import pandas
df = pandas.DataFrame(data={"Title_col_most_common_words": most_common_words1, "PRO_col_most_common_words": most_common_words2,
                             "CONS_col_most_common_words": most_common_words3})
df.to_csv("./most_common_words.csv", sep=',',index=False)

# %%
most_common_words_file=pd.read_csv('/content/most_common_words.csv')
most_common_words_file
# Out:
#      Title_col_most_common_words PRO_col_most_common_words  \
# 0                 [207, 'Great']             [1113, 'and']
# 1                    [207, 'to']               [814, 'to']
# 2                  [168, 'Good']              [660, 'the']
# 3                  [165, 'work']                [462, 'a']
# 4               [144, 'company']               [384, 'of']
# ..                           ...                       ...
# 930             [1, 'Coworkers']          [3, 'maintened']
# 931                [1, 'Spirit']          [3, 'everytime']
# 932  [1, 'Nuclearopportunities']          [3, 'Corporate']
# 933            [1, 'Apprentice']          [3, 'Customers']
# 934               [1, 'Slipped']              [3, 'apart']
#
#     CONS_col_most_common_words
# 0                [1413, 'the']
# 1                 [1316, 'to']
# 2                [1167, 'and']
# 3                   [744, 'a']
# 4                  [726, 'of']
# ..                         ...
# 930                 [6, 'up.']
# 931            [6, 'screamed']
# 932            [6, 'approach']
# 933            [6, 'external']
# 934              [6, 'ignore']
#
# [935 rows x 3 columns]

# %% [markdown]
# THE END OF IMPLEMENTATION.THANK YOU!!!
